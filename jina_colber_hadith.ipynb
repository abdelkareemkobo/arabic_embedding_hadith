# %%
from datasets import load_dataset

ds = load_dataset("arbml/Hadith")

# %%
ds['train'][0]
# Out:
# {'Text': 'أخبرنا قتيبة بن سعيد قال حدثنا سفيان عن الزهري عن أبي سلمة عن أبي هريرة أن النبي صلى الله عليه وسلم قال إذا استيقظ أحدكم من نومه فلا يغمس يده في وضوئه حتى يغسلها ثلاثا فإن أحدكم لا يدري أين باتت يده.'}

# %% [markdown]
# ## Load the model

# %%
from ragatouille import RAGPretrainedModel

RAG = RAGPretrainedModel.from_pretrained("jinaai/jina-colbert-v2")
# RAG = RAGPretrainedModel.from_pretrained("akhooli/arabic-colbertv2-711k-norm")
docs = [
    "ColBERT is a novel ranking model that adapts deep LMs for efficient retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
    "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
]
RAG.index(docs, index_name="demo",use_faiss=True)
query = "What does ColBERT do?"
results = RAG.search(query)
# Out:
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - configuration_xlm_roberta.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - mlp.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - stochastic_depth.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - rotary.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - mha.py
# - rotary.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - block.py
# - mlp.py
# - stochastic_depth.py
# - mha.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - xlm_padding.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - embedding.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - modeling_xlm_roberta.py
# - block.py
# - xlm_padding.py
# - embedding.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# /home/kareem/mambaforge/envs/IR/lib/python3.11/site-packages/flash_attn/ops/triton/layer_norm.py:984: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /home/kareem/mambaforge/envs/IR/lib/python3.11/site-packages/flash_attn/ops/triton/layer_norm.py:1043: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /home/kareem/mambaforge/envs/IR/lib/python3.11/site-packages/colbert/utils/amp.py:12: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler()
# ________________________________________________________________________________
# WARNING! You have a GPU available, but only `faiss-cpu` is currently installed.
#  This means that indexing will be slow. To make use of your GPU.
# Please install `faiss-gpu` by running:
# pip uninstall --y faiss-cpu & pip install faiss-gpu
#  ________________________________________________________________________________
# Will continue with CPU indexing in 5 seconds...
#
#
# [Nov 24, 12:06:07] #> Creating directory .ragatouille/colbert/indexes/demo
#
#
# [Nov 24, 12:06:17] [0] 		 #> Encoding 79 passages..
# /home/kareem/mambaforge/envs/IR/lib/python3.11/site-packages/colbert/utils/amp.py:15: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   return torch.cuda.amp.autocast() if self.activated else NullContextManager()
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 86
#       4 # RAG = RAGPretrainedModel.from_pretrained("akhooli/arabic-colbertv2-711k-norm")
#       5 docs = [
#       6     "ColBERT is a novel ranking model that adapts deep LMs for efficient retrieval.",
#       7     "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
#    (...)
#      84     "Jina-ColBERT is a ColBERT-style model but based on JinaBERT so it can support both 8k context length, fast and accurate retrieval.",
#      85 ]
# ---> 86 RAG.index(docs, index_name="demo",use_faiss=True)
#      87 query = "What does ColBERT do?"
#      88 results = RAG.search(query)
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/ragatouille/RAGPretrainedModel.py:211, in RAGPretrainedModel.index(self, collection, document_ids, document_metadatas, index_name, overwrite_index, max_document_length, split_documents, document_splitter_fn, preprocessing_fn, bsize, use_faiss)
#     202     document_splitter_fn = None
#     203 collection, pid_docid_map, docid_metadata_map = self._process_corpus(
#     204     collection,
#     205     document_ids,
#    (...)
#     209     max_document_length,
#     210 )
# --> 211 return self.model.index(
#     212     collection,
#     213     pid_docid_map=pid_docid_map,
#     214     docid_metadata_map=docid_metadata_map,
#     215     index_name=index_name,
#     216     max_document_length=max_document_length,
#     217     overwrite=overwrite_index,
#     218     bsize=bsize,
#     219     use_faiss=use_faiss,
#     220 )
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/ragatouille/models/colbert.py:341, in ColBERT.index(self, collection, pid_docid_map, docid_metadata_map, index_name, max_document_length, overwrite, bsize, use_faiss)
#     337     self.docid_pid_map[docid].append(pid)
#     339 self.docid_metadata_map = docid_metadata_map
# --> 341 self.model_index = ModelIndexFactory.construct(
#     342     "PLAID",
#     343     self.config,
#     344     self.checkpoint,
#     345     self.collection,
#     346     self.index_name,
#     347     overwrite,
#     348     verbose=self.verbose != 0,
#     349     bsize=bsize,
#     350     use_faiss=use_faiss,
#     351 )
#     352 self.config = self.model_index.config
#     353 self._save_index_metadata()
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/ragatouille/models/index.py:474, in ModelIndexFactory.construct(index_type, config, checkpoint, collection, index_name, overwrite, verbose, **kwargs)
#     471 if index_type == "auto":
#     472     # NOTE: For now only PLAID indexes are supported.
#     473     index_type = "PLAID"
# --> 474 return ModelIndexFactory._MODEL_INDEX_BY_NAME[
#     475     ModelIndexFactory._raise_if_invalid_index_type(index_type)
#     476 ].construct(
#     477     config, checkpoint, collection, index_name, overwrite, verbose, **kwargs
#     478 )
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/ragatouille/models/index.py:141, in PLAIDModelIndex.construct(config, checkpoint, collection, index_name, overwrite, verbose, **kwargs)
#     131 @staticmethod
#     132 def construct(
#     133     config: ColBERTConfig,
#    (...)
#     139     **kwargs,
#     140 ) -> "PLAIDModelIndex":
# --> 141     return PLAIDModelIndex(config).build(
#     142         checkpoint, collection, index_name, overwrite, verbose, **kwargs
#     143     )
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/ragatouille/models/index.py:243, in PLAIDModelIndex.build(self, checkpoint, collection, index_name, overwrite, verbose, **kwargs)
#     237     indexer = Indexer(
#     238         checkpoint=checkpoint,
#     239         config=self.config,
#     240         verbose=verbose,
#     241     )
#     242     indexer.configure(avoid_fork_if_possible=True)
# --> 243     indexer.index(name=index_name, collection=collection, overwrite=overwrite)
#     245 return self
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/colbert/indexer.py:80, in Indexer.index(self, name, collection, overwrite)
#      77     self.erase()
#      79 if index_does_not_exist or overwrite != 'reuse':
# ---> 80     self.__launch(collection)
#      82 return self.index_path
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/colbert/indexer.py:89, in Indexer.__launch(self, collection)
#      87     shared_queues = []
#      88     shared_lists = []
# ---> 89     launcher.launch_without_fork(self.config, collection, shared_lists, shared_queues, self.verbose)
#      91     return
#      93 manager = mp.Manager()
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/colbert/infra/launcher.py:93, in Launcher.launch_without_fork(self, custom_config, *args)
#      90 assert (custom_config.avoid_fork_if_possible or self.run_config.avoid_fork_if_possible)
#      92 new_config = type(custom_config).from_existing(custom_config, self.run_config, RunConfig(rank=0))
# ---> 93 return_val = run_process_without_mp(self.callee, new_config, *args)
#      95 return return_val
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/colbert/infra/launcher.py:109, in run_process_without_mp(callee, config, *args)
#     106 os.environ["CUDA_VISIBLE_DEVICES"] = ','.join(map(str, config.gpus_[:config.nranks]))
#     108 with Run().context(config, inherit_config=False):
# --> 109     return_val = callee(config, *args)
#     110     torch.cuda.empty_cache()
#     111     return return_val
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/colbert/indexing/collection_indexer.py:33, in encode(config, collection, shared_lists, shared_queues, verbose)
#      31 def encode(config, collection, shared_lists, shared_queues, verbose: int = 3):
#      32     encoder = CollectionIndexer(config=config, collection=collection, verbose=verbose)
# ---> 33     encoder.run(shared_lists)
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/colbert/indexing/collection_indexer.py:63, in CollectionIndexer.run(self, shared_lists)
#      61 def run(self, shared_lists):
#      62     with torch.inference_mode():
# ---> 63         self.setup() # Computes and saves plan for whole collection
#      64         distributed.barrier(self.rank)
#      65         print_memory_stats(f'RANK:{self.rank}')
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/colbert/indexing/collection_indexer.py:101, in CollectionIndexer.setup(self)
#      99 # Saves sampled passages and embeddings for training k-means centroids later
#     100 sampled_pids = self._sample_pids()
# --> 101 avg_doclen_est = self._sample_embeddings(sampled_pids)
#     103 # Select the number of partitions
#     104 num_passages = len(self.collection)
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/colbert/indexing/collection_indexer.py:137, in CollectionIndexer._sample_embeddings(self, sampled_pids)
#     134 local_pids = self.collection.enumerate(rank=self.rank)
#     135 local_sample = [passage for pid, passage in local_pids if pid in sampled_pids]
# --> 137 local_sample_embs, doclens = self.encoder.encode_passages(local_sample)
#     139 if torch.cuda.is_available():
#     140     if torch.distributed.is_available() and torch.distributed.is_initialized():
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/colbert/indexing/collection_encoder.py:26, in CollectionEncoder.encode_passages(self, passages)
#      22 # Batch here to avoid OOM from storing intermediate embeddings on GPU.
#      23 # Storing on the GPU helps with speed of masking, etc.
#      24 # But ideally this batching happens internally inside docFromText.
#      25 for passages_batch in batch(passages, self.config.index_bsize * 50):
# ---> 26     embs_, doclens_ = self.checkpoint.docFromText(passages_batch, bsize=self.config.index_bsize,
#      27                                                   keep_dims='flatten', showprogress=(not self.use_gpu))
#      28     embs.append(embs_)
#      29     doclens.extend(doclens_)
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/colbert/modeling/checkpoint.py:67, in Checkpoint.docFromText(self, docs, bsize, keep_dims, to_cpu, showprogress, return_tokens)
#      64     returned_text = [returned_text]
#      66 keep_dims_ = 'return_mask' if keep_dims == 'flatten' else keep_dims
# ---> 67 batches = [self.doc(input_ids, attention_mask, keep_dims=keep_dims_, to_cpu=to_cpu)
#      68            for input_ids, attention_mask in tqdm(text_batches, disable=not showprogress)]
#      70 if keep_dims is True:
#      71     D = _stack_3D_tensors(batches)
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/colbert/modeling/checkpoint.py:67, in <listcomp>(.0)
#      64     returned_text = [returned_text]
#      66 keep_dims_ = 'return_mask' if keep_dims == 'flatten' else keep_dims
# ---> 67 batches = [self.doc(input_ids, attention_mask, keep_dims=keep_dims_, to_cpu=to_cpu)
#      68            for input_ids, attention_mask in tqdm(text_batches, disable=not showprogress)]
#      70 if keep_dims is True:
#      71     D = _stack_3D_tensors(batches)
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/colbert/modeling/checkpoint.py:38, in Checkpoint.doc(self, to_cpu, *args, **kw_args)
#      36 with torch.no_grad():
#      37     with self.amp_manager.context():
# ---> 38         D = super().doc(*args, **kw_args)
#      40         if to_cpu:
#      41             return (D[0].cpu(), *D[1:]) if isinstance(D, tuple) else D.cpu()
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/colbert/modeling/colbert.py:99, in ColBERT.doc(self, input_ids, attention_mask, keep_dims)
#      96 assert keep_dims in [True, False, 'return_mask']
#      98 input_ids, attention_mask = input_ids.to(self.device), attention_mask.to(self.device)
# ---> 99 D = self.bert(input_ids, attention_mask=attention_mask)[0]
#     100 D = self.linear(D)
#     101 mask = torch.tensor(self.mask(input_ids, skiplist=self.skiplist), device=self.device).unsqueeze(2).float()
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.cache/huggingface/modules/transformers_modules/jinaai/xlm-roberta-flash-implementation/da863dd04a4e5dce6814c6625adfba87b83838aa/modeling_xlm_roberta.py:711, in XLMRobertaModel.forward(self, input_ids, position_ids, token_type_ids, attention_mask, masked_tokens_mask, return_dict, **kwargs)
#     708 else:
#     709     subset_mask = None
# --> 711 sequence_output = self.encoder(
#     712     hidden_states,
#     713     key_padding_mask=attention_mask,
#     714     subset_mask=subset_mask,
#     715     adapter_mask=adapter_mask,
#     716 )
#     718 if masked_tokens_mask is None:
#     719     pooled_output = (
#     720         self.pooler(sequence_output, adapter_mask=adapter_mask)
#     721         if self.pooler is not None
#     722         else None
#     723     )
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.cache/huggingface/modules/transformers_modules/jinaai/xlm-roberta-flash-implementation/da863dd04a4e5dce6814c6625adfba87b83838aa/modeling_xlm_roberta.py:241, in XLMRobertaEncoder.forward(self, hidden_states, key_padding_mask, subset_mask, adapter_mask)
#     234             hidden_states = torch.utils.checkpoint.checkpoint(
#     235                 layer,
#     236                 hidden_states,
#     237                 use_reentrant=self.use_reentrant,
#     238                 mixer_kwargs=mixer_kwargs,
#     239             )
#     240         else:
# --> 241             hidden_states = layer(hidden_states, mixer_kwargs=mixer_kwargs)
#     242     hidden_states = pad_input(hidden_states, indices, batch, seqlen)
#     243 else:
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.cache/huggingface/modules/transformers_modules/jinaai/xlm-roberta-flash-implementation/da863dd04a4e5dce6814c6625adfba87b83838aa/block.py:201, in Block.forward(self, hidden_states, residual, mixer_subset, mixer_kwargs)
#     199 else:
#     200     assert residual is None
# --> 201     mixer_out = self.mixer(
#     202         hidden_states, **(mixer_kwargs if mixer_kwargs is not None else {})
#     203     )
#     204     if self.return_residual:  # mixer out is actually a pair here
#     205         mixer_out, hidden_states = mixer_out
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.cache/huggingface/modules/transformers_modules/jinaai/xlm-roberta-flash-implementation/da863dd04a4e5dce6814c6625adfba87b83838aa/mha.py:740, in MHA.forward(self, x, x_kv, key_padding_mask, cu_seqlens, max_seqlen, mixer_subset, inference_params, adapter_mask, **kwargs)
#     738 if inference_params is None:
#     739     if not self.checkpointing:
# --> 740         context = self.inner_attn(qkv, **kwargs)
#     741     else:
#     742         context = torch.utils.checkpoint.checkpoint(
#     743             self.inner_attn, qkv, **kwargs
#     744         )
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/.cache/huggingface/modules/transformers_modules/jinaai/xlm-roberta-flash-implementation/da863dd04a4e5dce6814c6625adfba87b83838aa/mha.py:112, in FlashSelfAttention.forward(self, qkv, causal, cu_seqlens, max_seqlen)
#     110     assert max_seqlen is not None
#     111     assert isinstance(max_seqlen, int)
# --> 112     return flash_attn_varlen_qkvpacked_func(
#     113         qkv,
#     114         cu_seqlens,
#     115         max_seqlen,
#     116         self.drop.p if self.training else 0.0,
#     117         softmax_scale=self.softmax_scale,
#     118         causal=causal,
#     119         alibi_slopes=self.alibi_slopes,
#     120         window_size=self.window_size,
#     121         deterministic=self.deterministic,
#     122     )
#     123 else:
#     124     return flash_attn_qkvpacked_func(
#     125         qkv,
#     126         self.drop.p if self.training else 0.0,
#    (...)
#     131         deterministic=self.deterministic,
#     132     )
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/flash_attn/flash_attn_interface.py:1228, in flash_attn_varlen_qkvpacked_func(qkv, cu_seqlens, max_seqlen, dropout_p, softmax_scale, causal, window_size, softcap, alibi_slopes, deterministic, return_attn_probs)
#    1178 def flash_attn_varlen_qkvpacked_func(
#    1179     qkv,
#    1180     cu_seqlens,
#    (...)
#    1189     return_attn_probs=False,
#    1190 ):
#    1191     """dropout_p should be set to 0.0 during evaluation
#    1192     If Q, K, V are already stacked into 1 tensor, this function will be faster than
#    1193     calling flash_attn_varlen_func on Q, K, V since the backward pass avoids explicit concatenation
#    (...)
#    1226             pattern (negative means that location was dropped, nonnegative means it was kept).
#    1227     """
# -> 1228     return FlashAttnVarlenQKVPackedFunc.apply(
#    1229         qkv,
#    1230         cu_seqlens,
#    1231         max_seqlen,
#    1232         dropout_p,
#    1233         softmax_scale,
#    1234         causal,
#    1235         window_size,
#    1236         softcap,
#    1237         alibi_slopes,
#    1238         deterministic,
#    1239         return_attn_probs,
#    1240     )
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/torch/autograd/function.py:575, in Function.apply(cls, *args, **kwargs)
#     572 if not torch._C._are_functorch_transforms_active():
#     573     # See NOTE: [functorch vjp and autograd interaction]
#     574     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 575     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     577 if not is_setup_ctx_defined:
#     578     raise RuntimeError(
#     579         "In order to use an autograd.Function with functorch transforms "
#     580         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     581         "staticmethod. For more details, please see "
#     582         "https://pytorch.org/docs/main/notes/extending.func.html"
#     583     )
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/flash_attn/flash_attn_interface.py:539, in FlashAttnVarlenQKVPackedFunc.forward(ctx, qkv, cu_seqlens, max_seqlen, dropout_p, softmax_scale, causal, window_size, softcap, alibi_slopes, deterministic, return_softmax)
#     537     k = torch.nn.functional.pad(k, [0, 8 - head_size_og % 8])
#     538     v = torch.nn.functional.pad(v, [0, 8 - head_size_og % 8])
# --> 539 out_padded, softmax_lse, S_dmask, rng_state = _wrapped_flash_attn_varlen_forward(
#     540     q,
#     541     k,
#     542     v,
#     543     cu_seqlens,
#     544     cu_seqlens,
#     545     max_seqlen,
#     546     max_seqlen,
#     547     dropout_p,
#     548     softmax_scale,
#     549     causal=causal,
#     550     window_size_left=window_size[0],
#     551     window_size_right=window_size[1],
#     552     softcap=softcap,
#     553     alibi_slopes=alibi_slopes,
#     554     return_softmax=return_softmax and dropout_p > 0,
#     555     block_table=None,
#     556 )
#     557 ctx.save_for_backward(q, k, v, out_padded, softmax_lse, cu_seqlens, rng_state)
#     558 ctx.dropout_p = dropout_p
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/torch/_ops.py:1116, in OpOverloadPacket.__call__(self, *args, **kwargs)
#    1114 if self._has_torchbind_op_overload and _must_dispatch_in_python(args, kwargs):
#    1115     return _call_overload_packet_from_python(self, args, kwargs)
# -> 1116 return self._op(*args, **(kwargs or {}))
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/torch/_library/custom_ops.py:324, in CustomOpDef.register_kernel.<locals>.inner.<locals>.backend_impl(*args, **kwargs)
#     316 def backend_impl(*args, **kwargs):
#     317     # Checks the assumption that outputs cannot alias
#     318     # inputs or other outputs.
#     319     storages = {
#     320         id(tensor.untyped_storage())
#     321         for tensor in iter_tensors(args, kwargs)
#     322     }
# --> 324     result = self._backend_fns[device_type](*args, **kwargs)
#     326     tuple_result = result
#     327     if not isinstance(result, tuple):
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/torch/_compile.py:32, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      29     disable_fn = torch._dynamo.disable(fn, recursive)
#      30     fn.__dynamo_disable = disable_fn
# ---> 32 return disable_fn(*args, **kwargs)
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:632, in DisableContext.__call__.<locals>._fn(*args, **kwargs)
#     630 prior = _maybe_set_eval_frame(callback)
#     631 try:
# --> 632     return fn(*args, **kwargs)
#     633 finally:
#     634     _maybe_set_eval_frame(prior)
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/torch/_library/custom_ops.py:367, in CustomOpDef.register_kernel.<locals>.inner.<locals>.wrapped_fn(*args, **kwargs)
#     365     return self._init_fn(*args, **kwargs)
#     366 else:
# --> 367     return fn(*args, **kwargs)
#
# File ~/mambaforge/envs/IR/lib/python3.11/site-packages/flash_attn/flash_attn_interface.py:164, in _flash_attn_varlen_forward(q, k, v, cu_seqlens_q, cu_seqlens_k, max_seqlen_q, max_seqlen_k, dropout_p, softmax_scale, causal, window_size_left, window_size_right, softcap, alibi_slopes, return_softmax, block_table, leftpad_k, seqused_k)
#     142 @_torch_custom_op_wrapper("flash_attn::_flash_attn_varlen_forward", mutates_args=(), device_types="cuda")
#     143 def _flash_attn_varlen_forward(
#     144     q: torch.Tensor,
#    (...)
#     161     seqused_k: Optional[torch.Tensor] = None,
#     162 ) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor, torch.Tensor]:
#     163     q, k, v = [maybe_contiguous(x) for x in (q, k, v)]
# --> 164     out, softmax_lse, S_dmask, rng_state = flash_attn_cuda.varlen_fwd(
#     165         q,
#     166         k,
#     167         v,
#     168         None,
#     169         cu_seqlens_q,
#     170         cu_seqlens_k,
#     171         seqused_k,
#     172         leftpad_k,
#     173         block_table,
#     174         alibi_slopes,
#     175         max_seqlen_q,
#     176         max_seqlen_k,
#     177         dropout_p,
#     178         softmax_scale,
#     179         False,
#     180         causal,
#     181         window_size_left,
#     182         window_size_right,
#     183         softcap,
#     184         return_softmax,
#     185         None,
#     186     )
#     187     # if out.isnan().any() or softmax_lse.isnan().any():
#     188     #     breakpoint()
#     189     return out, softmax_lse, S_dmask, rng_state
#
# RuntimeError: FlashAttention only supports Ampere GPUs or newer.
